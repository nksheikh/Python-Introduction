# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Student_Performance.csv")
data = data.drop('Extracurricular Activities', axis = 1).drop('Performance Index', axis = 1)

# %%
X = data.to_numpy()
X_std = X - np.mean(X, axis = 0)
np.matmul(X_std.T, X_std)
# Out:
# array([[ 6.70384959e+04, -5.56335530e+03,  5.46726000e+01,
#          1.29641430e+03],
#        [-5.56335530e+03,  3.00754852e+06,  1.74811580e+03,
#          3.92223190e+03],
#        [ 5.46726000e+01,  1.74811580e+03,  2.87566364e+04,
#          1.94010200e+02],
#        [ 1.29641430e+03,  3.92223190e+03,  1.94010200e+02,
#          8.22086111e+04]])

# %%
# Out:
# array([[84, 82, 81, 89, 73, 94, 92, 70, 88, 95],
#        [85, 82, 72, 77, 75, 89, 95, 84, 77, 94],
#        [97, 94, 93, 95, 88, 82, 78, 84, 69, 78]])
